# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('images/monalisa.jpeg')
plt.imshow(img1[:,:,::-1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
result = DeepFace.analyze(img1, actions=['emotion'])
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]

# %%
print(result)
# Out:
# [{'emotion': {'angry': 0.05656162485469876, 'disgust': 0.00017795799597052832, 'fear': 0.09644736405020822, 'happy': 66.05050755149216, 'sad': 1.0438928693703258, 'surprise': 0.02542534214858319, 'neutral': 32.72698613726927}, 'dominant_emotion': 'happy', 'region': {'x': 56, 'y': 42, 'w': 56, 'h': 56}}]

# %%
print(result[0]['dominant_emotion'])
# Out:
# happy
